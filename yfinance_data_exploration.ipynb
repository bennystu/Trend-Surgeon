# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Using cached yfinance-0.2.66-py2.py3-none-any.whl.metadata (6.0 kB)
# Collecting pandas>=1.3.0 (from yfinance)
#   Using cached pandas-2.3.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (91 kB)
# Collecting numpy>=1.16.5 (from yfinance)
#   Using cached numpy-2.3.5-cp312-cp312-macosx_14_0_arm64.whl.metadata (62 kB)
# Requirement already satisfied: requests>=2.31 in /Users/pnl1f276/.pyenv/versions/Trend-Surgeon/lib/python3.12/site-packages (from yfinance) (2.32.5)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Using cached multitasking-0.0.12-py3-none-any.whl
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/pnl1f276/.pyenv/versions/Trend-Surgeon/lib/python3.12/site-packages (from yfinance) (4.5.0)
# Collecting pytz>=2022.5 (from yfinance)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Using cached frozendict-2.4.7-py3-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Using cached peewee-3.18.3-cp312-cp312-macosx_15_0_arm64.whl
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/pnl1f276/.pyenv/versions/Trend-Surgeon/lib/python3.12/site-packages (from yfinance) (4.14.3)
# Collecting curl_cffi>=0.7 (from yfinance)
#   Using cached curl_cffi-0.13.0-cp39-abi3-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting protobuf>=3.19.0 (from yfinance)
#   Using cached protobuf-6.33.1-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Collecting websockets>=13.0 (from yfinance)
#   Using cached websockets-15.0.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/pnl1f276/.pyenv/versions/Trend-Surgeon/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/pnl1f276/.pyenv/versions/Trend-Surgeon/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=1.12.0 in /Users/pnl1f276/.pyenv/versions/Trend-Surgeon/lib/python3.12/site-packages (from curl_cffi>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /Users/pnl1f276/.pyenv/versions/Trend-Surgeon/lib/python3.12/site-packages (from curl_cffi>=0.7->yfinance) (2025.11.12)
# Requirement already satisfied: pycparser in /Users/pnl1f276/.pyenv/versions/Trend-Surgeon/lib/python3.12/site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.23)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/pnl1f276/.pyenv/versions/Trend-Surgeon/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/pnl1f276/.pyenv/versions/Trend-Surgeon/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/pnl1f276/.pyenv/versions/Trend-Surgeon/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/pnl1f276/.pyenv/versions/Trend-Surgeon/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/pnl1f276/.pyenv/versions/Trend-Surgeon/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/pnl1f276/.pyenv/versions/Trend-Surgeon/lib/python3.12/site-packages (from requests>=2.31->yfinance) (2.5.0)
# Using cached yfinance-0.2.66-py2.py3-none-any.whl (123 kB)
# Using cached curl_cffi-0.13.0-cp39-abi3-macosx_11_0_arm64.whl (3.0 MB)
# Using cached frozendict-2.4.7-py3-none-any.whl (16 kB)
# Using cached numpy-2.3.5-cp312-cp312-macosx_14_0_arm64.whl (5.1 MB)
# Using cached pandas-2.3.3-cp312-cp312-macosx_11_0_arm64.whl (10.7 MB)
# Using cached protobuf-6.33.1-cp39-abi3-macosx_10_9_universal2.whl (427 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached websockets-15.0.1-cp312-cp312-macosx_11_0_arm64.whl (173 kB)
# Installing collected packages: pytz, peewee, multitasking, websockets, protobuf, numpy, frozendict, pandas, curl_cffi, yfinance
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [yfinance]  7/10 [pandas]f]s]
# Successfully installed curl_cffi-0.13.0 frozendict-2.4.7 multitasking-0.0.12 numpy-2.3.5 pandas-2.3.3 peewee-3.18.3 protobuf-6.33.1 pytz-2025.2 websockets-15.0.1 yfinance-0.2.66

# %%
pip install sklearn
# Out:
# Collecting sklearn
#   Downloading sklearn-0.0.post12.tar.gz (2.6 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
#         it would be great if you take some time to track which package uses
#         'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#       - as a last resort, set the environment variable
#         SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#       More information is available at
#       https://github.com/scikit-learn/sklearn-pypi-package
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ERROR: Failed to build 'sklearn' when getting requirements to build wheel
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.2-cp312-cp312-macosx_12_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.22.0 in /Users/pnl1f276/.pyenv/versions/Trend-Surgeon/lib/python3.12/site-packages (from scikit-learn) (2.3.5)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Downloading scipy-1.16.3-cp312-cp312-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.7.2-cp312-cp312-macosx_12_0_arm64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 26.8 MB/s  0:00:000.9 MB/s eta 0:00:01
# Using cached joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading scipy-1.16.3-cp312-cp312-macosx_14_0_arm64.whl (20.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 40.5 MB/s  0:00:002.6 MB/s eta 0:00:01
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [scikit-learn]0m 3/4 [scikit-learn]
# Successfully installed joblib-1.5.2 scikit-learn-1.7.2 scipy-1.16.3 threadpoolctl-3.6.0

# %%
import yfinance as yf
import pandas as pd
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
df = yf.download("SPY", start="2018-01-01", end="2022-12-31")
df = df.rename(columns=str.lower).dropna()
# Out:
# /var/folders/qc/49jwnztd1_n2k4yss03b1lkh0000gn/T/ipykernel_30969/1527677280.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download("SPY", start="2018-01-01", end="2022-12-31")
# [*********************100%***********************]  1 of 1 completed

# %%
df.shape
# Out:
# (1259, 5)

# %%
df.head(5)
# Out:
# Price            close        high         low        open    volume
# Ticker             spy         spy         spy         spy       spy
# Date
# 2018-01-02  237.909134  237.944549  236.696445  237.085925  86655700
# 2018-01-03  239.413956  239.564448  238.077329  238.077329  90070400
# 2018-01-04  240.423019  240.909883  239.475900  240.060120  80636400
# 2018-01-05  242.025238  242.149149  240.724026  241.219723  83524000
# 2018-01-08  242.467865  242.627190  241.635796  241.927893  57319200
